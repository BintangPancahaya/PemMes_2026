# %% [markdown]
# <a href="https://colab.research.google.com/github/BintangPancahaya/PemMes_2026/blob/main/JS02/JS02_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Membaca dataset
df = pd.read_csv("wbc.csv")

# Melihat ukuran dataset
print("Ukuran dataset:", df.shape)
# Out:
# Ukuran dataset: (569, 33)

# %%
# Memisahkan variabel

df_clean = df.drop(columns=["id", "Unnamed: 32"])

# %%
# Encoding Diagnosis

df_clean["diagnosis"] = df_clean["diagnosis"].map({
    "M": 1,
    "B": 0
})

X = df_clean.drop(columns=["diagnosis"])
y = df_clean["diagnosis"]

# %%
# Standarisasi
scaler = StandardScaler()

X_scaled = pd.DataFrame(
    scaler.fit_transform(X),
    columns=X.columns
)

# %%
df_final = pd.concat(
    [X_scaled, y.reset_index(drop=True)],
    axis=1
)

# %%
# Menampilkan hasil
print("Jumlah variabel prediktor:", X.shape[1])
print("\n10 data pertama setelah preprocessing:")
display(df_final.head(10))
# Out:
# Jumlah variabel prediktor: 30
#
# 10 data pertama setelah preprocessing:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
# 5    -0.476375     -0.835335       -0.387148  -0.505650         2.237421
# 6     1.170908      0.160649        1.138125   1.095295        -0.123136
# 7    -0.118517      0.358450       -0.072867  -0.218965         1.604049
# 8    -0.320167      0.588830       -0.184080  -0.384207         2.201839
# 9    -0.473535      1.105439       -0.329482  -0.509063         1.582699
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# ...
